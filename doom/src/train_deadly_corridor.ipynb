# %%
# defend the center scenario
import sys
import os
sys.path.append('..') # make sure files dont violate this convention


from envs.doom_env import VizDoomGymCorridor, DoomEpisodeLoggerCallback
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback, CallbackList
from stable_baselines3 import PPO
import torch

# CONFIG STUFF HERE
MODEL_SCENARIO_NAME = 'ppo_deadly_corridor'
SCENARIO_PATH = '../scenarios/deadly_corridor.cfg'
LOG_DIR = f'../logs/{MODEL_SCENARIO_NAME}/'
MODEL_DIR = f'../models/{MODEL_SCENARIO_NAME}/'
NUM_ENVS = 8

os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# seeding the training
import random
import numpy as np
from stable_baselines3.common.utils import set_random_seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
set_random_seed(SEED)

# %%
env = make_vec_env(
    VizDoomGymCorridor, # my doom environment
    n_envs=NUM_ENVS,
    env_kwargs=dict(
        scenario_path=SCENARIO_PATH,
        render=False,
        number_of_actions=7,
    ),
    vec_env_cls=DummyVecEnv,  # Auto-selects SubprocVecEnv (Linux) or DummyVecEnv (Windows)
    seed=SEED
)

# %%
# setting loggers and checkpoints for the model
checkpoint_callback = CheckpointCallback(save_freq=10000 // NUM_ENVS, save_path=MODEL_DIR,name_prefix=MODEL_SCENARIO_NAME)
episode_logger = DoomEpisodeLoggerCallback(log_dir=LOG_DIR, log_file=f"{MODEL_SCENARIO_NAME}_episodes_v1.csv", verbose=0)

combined_callback = CallbackList([checkpoint_callback, episode_logger])

# creating the model
model = PPO(
        "CnnPolicy",
        env,
        verbose=1,
        tensorboard_log=LOG_DIR,
        device="cuda" if torch.cuda.is_available() else "cpu",
        learning_rate=2.5e-4,
        n_steps=4096,
        batch_size=2048,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.1,
        ent_coef=0.01,
        vf_coef=0.5,
        max_grad_norm=0.5,
        seed=SEED
    )
env.reset()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# array([[[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]],
#
#
#        [[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]],
#
#
#        [[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]],
#
#
#        ...,
#
#
#        [[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]],
#
#
#        [[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]],
#
#
#        [[[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         [[159],
#          [160],
#          [150],
#          ...,
#          [191],
#          [195],
#          [199]],
#
#         ...,
#
#         [[111],
#          [ 91],
#          [ 86],
#          ...,
#          [ 74],
#          [ 68],
#          [ 54]],
#
#         [[104],
#          [ 94],
#          [ 87],
#          ...,
#          [ 65],
#          [ 70],
#          [ 46]],
#
#         [[103],
#          [ 82],
#          [ 84],
#          ...,
#          [ 49],
#          [ 51],
#          [ 47]]]], shape=(8, 100, 160, 1), dtype=uint8)

# %% [markdown]
# 2.6 hours for 100k steps
#
# 10.64 fps

# %%
torch.cuda.get_device_name(0)
torch.cuda.is_available()
# Out:
# True

# %%
model.learn(
        total_timesteps=100_000 // NUM_ENVS * NUM_ENVS,
        callback=combined_callback,2415
        progress_bar=True,
        tb_log_name=MODEL_SCENARIO_NAME
)

model.save(os.path.join(MODEL_DIR, "ppo_deadly_corridor_100k_final"))
env.close()
print(f"\nTraining complete. Model saved to {MODEL_DIR}")
# Out:
# Logging to ../logs/ppo_deadly_corridor/ppo_deadly_corridor_3
# c:\Users\Sid\Documents\VizDoom\venv\lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    fps             | 10       |
# |    iterations      | 1        |
# |    time_elapsed    | 3070     |
# |    total_timesteps | 32768    |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 37.6      |
# |    ep_rew_mean          | 765       |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 2         |
# |    time_elapsed         | 6160      |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 1.4093097 |
# |    clip_fraction        | 0.698     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -1.77     |
# |    explained_variance   | 0.000181  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 1.43e+05  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | 0.0702    |
# |    value_loss           | 3.2e+05   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 54        |
# |    ep_rew_mean          | -1.21e+03 |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 3         |
# |    time_elapsed         | 9223      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 22.701092 |
# |    clip_fraction        | 0.947     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.903    |
# |    explained_variance   | 0.126     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 2.04e+05  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.303     |
# |    value_loss           | 4.04e+05  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 50       |
# |    ep_rew_mean          | -905     |
# | time/                   |          |
# |    fps                  | 10       |
# |    iterations           | 4        |
# |    time_elapsed         | 12300    |
# |    total_timesteps      | 131072   |
# | train/                  |          |
# |    approx_kl            | 7.242805 |
# |    clip_fraction        | 0.878    |
# |    clip_range           | 0.1      |
# |    entropy_loss         | -0.0662  |
# |    explained_variance   | -1.54    |
# |    learning_rate        | 0.00025  |
# |    loss                 | 3.31e+04 |
# |    n_updates            | 30       |
# |    policy_gradient_loss | 0.247    |
# |    value_loss           | 9.5e+04  |
# --------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training complete. Model saved to ../models/ppo_deadly_corridor/

# %%
import time
# from vizdoom import ScreenResolution
# import cv2

# VIDEO_DIR = '../videos/'
# os.makedirs(VIDEO_DIR, exist_ok=True)
# VIDEO_PATH = os.path.join(VIDEO_DIR, "defend_center_ppo.mp4")

env = VizDoomGymCorridor(SCENARIO_PATH, render=True)

model = PPO.load(f"{MODEL_DIR}ppo_deadly_corridor_100k_final")


for ep in range(100):
    obs, info = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        total_reward += reward
        time.sleep(0.02)
    
    # print(f"Episode {ep+1} reward: {total_reward}")
    # print(f"Video saved to {VIDEO_DIR}")

env.close()
# Out:
# ---------------------------------------------------------------------------
# ViZDoomUnexpectedExitException            Traceback (most recent call last)
# Cell In[7], line 20
#      18 while not done:
#      19     action, _ = model.predict(obs)
# ---> 20     obs, reward, terminated, truncated, info = env.step(action)
#      21     done = terminated or truncated
#      22     total_reward += reward
#
# File c:\Users\Sid\Documents\VizDoom\src\..\envs\doom_env.py:252, in VizDoomGymCorridor.step(self, action)
#     245 """
#     246 Executes one environment step using the chosen action.
#     247 Returns next_state, reward, terminated, truncated, info.
#     248
#     249 For performing reward shaping on the scenario
#     250 """
#     251 actions = np.identity(7)
# --> 252 movement_reward = self.game.make_action(actions[action], 4)  # Perform action for 4 tics
#     253 time.sleep(0.05)
#     255 reward = 0
#
# ViZDoomUnexpectedExitException: Controlled ViZDoom instance exited unexpectedly.
